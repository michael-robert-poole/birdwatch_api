# %%
from tensorflow import keras
model = keras.models.load_model('f')

# %%
import cv2
theImage=cv2.imread("x.jpeg", cv2.IMREAD_COLOR)
img_resize = cv2.resize(theImage, (256,256))
img_rgb = cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB)
img = img_rgb.reshape(1,256,256,3)

# %%
x = model.predict(img)

# %%
str(x)
# Out:
# '[[2.0064579e-04 2.5555137e-06 9.4273219e-06 9.9601680e-01 6.4819462e-05\n  8.8609231e-04 1.2792657e-04 2.4596639e-03 2.1773497e-04 1.4217072e-05]]'

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.reshape(256,256,3))

# %%
import tensorflow as tf
image_size = (256, 256)
batch_size = 32
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "val_ten_uk_birds/",
    labels="inferred",
    label_mode="int",
    color_mode="rgb",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size
)
# Out:
# Found 100 files belonging to 10 classes.

# %%
model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 8s 2s/step - loss: 1.6526 - accuracy: 0.4800
# [1.6526070833206177, 0.47999998927116394]
